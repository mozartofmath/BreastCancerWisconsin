# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../scripts")
from Plotting import plot_hist, plot_count

# %%
import logging
logging.basicConfig(format='%(asctime)s %(message)s', level=logging.DEBUG)

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('../data/data.csv')

# %% [markdown]
# ## Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df = df.drop('Unnamed: 32', axis = 1)

# %% [markdown]
# ## Visualization

# %%
plot_count(df, 'diagnosis')
# Out:
# 2021-08-26 03:08:56,752 plotted count plot for column diagnosis

# %%
plot_hist(df, 'radius_mean', 'blue')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# 2021-08-26 03:08:58,659 plotted histogram for column radius_mean

# %%
plot_hist(df, 'texture_mean', 'blue')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# 2021-08-26 03:09:00,534 plotted histogram for column texture_mean

# %% [markdown]
# ## Correlation

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.drop('id', axis = 1).corr(), fignum=f.number)
plt.xticks(range(df.drop('id', axis = 1).select_dtypes(['number']).shape[1]), df.drop('id', axis = 1).select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.drop('id', axis = 1).select_dtypes(['number']).shape[1]), df.drop('id', axis = 1).select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
# Out:
# 2021-08-26 03:09:27,018 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000041821A6CF8>
# 2021-08-26 03:09:27,020 Using auto colorbar locator on colorbar
# 2021-08-26 03:09:27,022 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000041821A6CF8>
# 2021-08-26 03:09:27,025 Setting pcolormesh
# 2021-08-26 03:09:27,068 not adjusting title pos because a title was already placed manually: 1.050000
# 2021-08-26 03:09:27,840 title position was updated manually, not adjusting
# 2021-08-26 03:09:29,026 title position was updated manually, not adjusting
# 2021-08-26 03:09:29,031 title position was updated manually, not adjusting
# 2021-08-26 03:09:29,462 title position was updated manually, not adjusting
# 2021-08-26 03:09:29,467 title position was updated manually, not adjusting
# 2021-08-26 03:09:29,565 title position was updated manually, not adjusting

# %% [markdown]
# ## Labeling

# %%
def label(x):
    if x == 'B':
        return 0
    else:
        return 1

# %%
df['diagnosis'] = df['diagnosis'].apply(label)

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df[['id', 'diagnosis']].groupby('diagnosis').count()
# Out:
#             id
# diagnosis
# 0          357
# 1          212

# %% [markdown]
# ## Prepare Training Set

# %%
X, y = df.drop(['id', 'diagnosis'], axis = 1), df['diagnosis']

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X.shape
# Out:
# (569, 30)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=23)

# %% [markdown]
# ## Logistic Regression Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
log_reg = make_pipeline(StandardScaler(), LogisticRegression(random_state=0))
log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(random_state=0))])

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.990234375

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = log_reg[-1].coef_[0])

# %%
df.drop(['id', 'diagnosis'], axis = 1).columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rand_forest = make_pipeline(StandardScaler(), RandomForestClassifier(max_depth=3, random_state=0))
rand_forest.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=3, random_state=0))])

# %%
rand_forest.score(X_train, y_train)
# Out:
# 0.984375

# %%
rand_forest.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = rand_forest[-1].feature_importances_)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(kernel='linear', gamma='auto'))
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto', kernel='linear'))])

# %%
clf.score(X_train, y_train)
# Out:
# 0.98828125

# %%
clf.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = clf[-1].coef_[0])

# %% [markdown]
# ## ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Out:
# 2021-08-26 04:15:06,434 Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2021-08-26 04:15:12,353 Creating converter from 7 to 5
# 2021-08-26 04:15:12,357 Creating converter from 5 to 7
# 2021-08-26 04:15:12,360 Creating converter from 7 to 5
# 2021-08-26 04:15:12,364 Creating converter from 5 to 7

# %%
model = Sequential()
model.add(Dense(12, input_dim = X_train.shape[-1], activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 52/52 [==============================] - 6s 21ms/step - loss: 0.4272 - accuracy: 0.8359 - val_loss: 0.2863 - val_accuracy: 0.9123
# Epoch 2/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.3116 - accuracy: 0.8867 - val_loss: 0.1984 - val_accuracy: 0.9298
# Epoch 3/20
# 52/52 [==============================] - 0s 8ms/step - loss: 0.2468 - accuracy: 0.9297 - val_loss: 0.1577 - val_accuracy: 0.9474
# Epoch 4/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1900 - accuracy: 0.9531 - val_loss: 0.1365 - val_accuracy: 0.9474
# Epoch 5/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 0.9492 - val_loss: 0.1252 - val_accuracy: 0.9474
# Epoch 6/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1454 - accuracy: 0.9570 - val_loss: 0.1208 - val_accuracy: 0.9474
# Epoch 7/20
# ...
