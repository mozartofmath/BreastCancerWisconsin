# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../scripts")
from Plotting import Plotter
from label import label

# %%
import logging
logging.basicConfig(format='%(asctime)s %(message)s', level=logging.INFO)

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('../data/data.csv')

# %% [markdown]
# ## Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
# Unnamed: 32                0.0           NaN           NaN          NaN
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
# Unnamed: 32                        NaN            NaN           NaN
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01
# Unnamed: 32                       NaN

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df = df.drop('Unnamed: 32', axis = 1)

# %% [markdown]
# ## Visualization

# %%
vis =  Plotter()

# %%
vis.plot_count(df, 'diagnosis')
#plt.show()
# Out:
# 2021-08-26 06:06:57,620 plotted count plot for column diagnosis

# %%
vis.plot_hist(df, 'radius_mean', 'blue')
# Out:
# 2021-08-26 06:07:00,800 plotted histogram for column radius_mean

# %%
vis.plot_hist(df, 'texture_mean', 'blue')
# Out:
# 2021-08-26 06:07:04,018 plotted histogram for column texture_mean

# %% [markdown]
# ## Correlation

# %%
vis.plot_correlation(df.drop('id', axis = 1), "Correlation Matrix")
# Out:
# 2021-08-26 06:07:04,786 plotted correlation matrix

# %% [markdown]
# ## Labeling

# %%
df['diagnosis'] = df['diagnosis'].apply(label)

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df[['id', 'diagnosis']].groupby('diagnosis').count()
# Out:
#             id
# diagnosis
# 0          357
# 1          212

# %% [markdown]
# ## Prepare Training Set

# %%
X, y = df.drop(['id', 'diagnosis'], axis = 1), df['diagnosis']

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X.shape
# Out:
# (569, 30)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=23)

# %% [markdown]
# ## Logistic Regression Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
log_reg = make_pipeline(StandardScaler(), LogisticRegression(random_state=0))
log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(random_state=0))])

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.990234375

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = log_reg[-1].coef_[0])

# %%
df.drop(['id', 'diagnosis'], axis = 1).columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rand_forest = make_pipeline(StandardScaler(), RandomForestClassifier(max_depth=3, random_state=0))
rand_forest.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=3, random_state=0))])

# %%
rand_forest.score(X_train, y_train)
# Out:
# 0.984375

# %%
rand_forest.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = rand_forest[-1].feature_importances_)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(kernel='linear', gamma='auto'))
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto', kernel='linear'))])

# %%
clf.score(X_train, y_train)
# Out:
# 0.98828125

# %%
clf.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
plt.figure(figsize=(12,7))
sns.barplot(y = df.drop(['id', 'diagnosis'], axis = 1).columns, x = clf[-1].coef_[0])

# %% [markdown]
# ## ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Out:
# 2021-08-26 04:15:06,434 Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2021-08-26 04:15:12,353 Creating converter from 7 to 5
# 2021-08-26 04:15:12,357 Creating converter from 5 to 7
# 2021-08-26 04:15:12,360 Creating converter from 7 to 5
# 2021-08-26 04:15:12,364 Creating converter from 5 to 7

# %%
model = Sequential()
model.add(Dense(12, input_dim = X_train.shape[-1], activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 52/52 [==============================] - 3s 13ms/step - loss: 0.6666 - accuracy: 0.5664 - val_loss: 0.4933 - val_accuracy: 0.7895
# Epoch 2/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.4683 - accuracy: 0.7949 - val_loss: 0.2976 - val_accuracy: 0.9298
# Epoch 3/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.3312 - accuracy: 0.8652 - val_loss: 0.1995 - val_accuracy: 0.9298
# Epoch 4/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2712 - accuracy: 0.8867 - val_loss: 0.1577 - val_accuracy: 0.9298
# Epoch 5/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2170 - accuracy: 0.9102 - val_loss: 0.1388 - val_accuracy: 0.9298
# Epoch 6/20
# 52/52 [==============================] - 0s 8ms/step - loss: 0.2133 - accuracy: 0.9121 - val_loss: 0.1335 - val_accuracy: 0.9474
# Epoch 7/20
# 52/52 [==============================] - 0s 7ms/step - loss: 0.1836 - accuracy: 0.9258 - val_loss: 0.1298 - val_accuracy: 0.9474
# Epoch 8/20
# 52/52 [==============================] - 0s 8ms/step - loss: 0.1445 - accuracy: 0.9453 - val_loss: 0.1251 - val_accuracy: 0.9474
# Epoch 9/20
# 52/52 [==============================] - 0s 8ms/step - loss: 0.1424 - accuracy: 0.9453 - val_loss: 0.1215 - val_accuracy: 0.9474
# Epoch 10/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1234 - accuracy: 0.9609 - val_loss: 0.1207 - val_accuracy: 0.9474
# Epoch 11/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9512 - val_loss: 0.1214 - val_accuracy: 0.9474
# Epoch 12/20
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0979 - accuracy: 0.9668 - val_loss: 0.1196 - val_accuracy: 0.9474
# Epoch 13/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1074 - accuracy: 0.9551 - val_loss: 0.1232 - val_accuracy: 0.9474
# Epoch 14/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.9531 - val_loss: 0.1231 - val_accuracy: 0.9649
# Epoch 15/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9688 - val_loss: 0.1240 - val_accuracy: 0.9649
# Epoch 16/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0850 - accuracy: 0.9707 - val_loss: 0.1253 - val_accuracy: 0.9649
# Epoch 17/20
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0963 - accuracy: 0.9609 - val_loss: 0.1256 - val_accuracy: 0.9649
# Epoch 18/20
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0926 - accuracy: 0.9629 - val_loss: 0.1333 - val_accuracy: 0.9649
# Epoch 19/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0974 - accuracy: 0.9727 - val_loss: 0.1331 - val_accuracy: 0.9649
# Epoch 20/20
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0675 - accuracy: 0.9785 - val_loss: 0.1359 - val_accuracy: 0.9649

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
history.history
# Out:
# {'loss': [0.6666237711906433,
#   0.4683394730091095,
#   0.3311556577682495,
#   0.27124443650245667,
#   0.21699994802474976,
#   0.21333783864974976,
#   0.18358851969242096,
#   0.14449918270111084,
#   0.14236672222614288,
#   0.12344487011432648,
#   0.12837865948677063,
#   0.09789122641086578,
#   0.10744288563728333,
#   0.10940371453762054,
#   0.10328298807144165,
#   0.0850447490811348,
#   0.09631668776273727,
#   0.0925794392824173,
#   0.09739242494106293,
#   0.06754684448242188],
#  'accuracy': [0.56640625,
#   0.794921875,
#   0.865234375,
#   0.88671875,
#   0.91015625,
#   0.912109375,
#   0.92578125,
#   0.9453125,
#   0.9453125,
#   0.9609375,
#   0.951171875,
#   0.966796875,
#   0.955078125,
#   0.953125,
#   0.96875,
#   0.970703125,
#   0.9609375,
#   0.962890625,
#   0.97265625,
#   0.978515625],
#  'val_loss': [0.4933181703090668,
#   0.29760995507240295,
#   0.19954179227352142,
#   0.15765529870986938,
#   0.13884547352790833,
#   0.1334519237279892,
#   0.12979620695114136,
#   0.1251157820224762,
#   0.1215478926897049,
#   0.12071999907493591,
#   0.12144806981086731,
#   0.11959030479192734,
#   0.1231640949845314,
#   0.12312666326761246,
#   0.12396985292434692,
#   0.12529334425926208,
#   0.12559807300567627,
#   0.13334104418754578,
#   0.13311287760734558,
#   0.13593949377536774],
#  'val_accuracy': [0.7894737124443054,
#   0.9298245906829834,
#   0.9298245906829834,
#   0.9298245906829834,
#   0.9298245906829834,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9473684430122375,
#   0.9649122953414917,
#   0.9649122953414917,
#   0.9649122953414917,
#   0.9649122953414917,
#   0.9649122953414917,
#   0.9649122953414917,
#   0.9649122953414917]}
